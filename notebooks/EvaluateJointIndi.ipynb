# %%
import sys
sys.path.append('..')

# %%
ckpt = '2410/Hagen-joint_indi-l1/27'
training_rootdir = '/group/jug/ashesh/training/diffsplit/'
num_timesteps = 1



ckpt = ckpt.strip('/').strip(' ')
ckpt
# Out:
# '2410/Hagen-joint_indi-l1/27'

# %%
import yaml
import os
import glob

def model_checkpoint_fpath(fname=None):
    ckpt_dir = os.path.join(training_rootdir, ckpt, 'checkpoint')
    if fname is not None:
        return os.path.join(training_rootdir, ckpt, fname)
    else:
        list_of_files = glob.glob(ckpt_dir +'/*_gen.pth') # * means all if need specific format then *.csv
        latest_file = max(list_of_files, key=os.path.getctime)
        fname = latest_file
        return os.path.join(ckpt_dir,latest_file)

def model_checkpoint_fpath_prefix(fname=None):
    fpath = model_checkpoint_fpath(fname)
    suffix = '_gen.pth'
    assert fpath.endswith(suffix)
    return fpath[:-len(suffix)]

def load_config(ckpt):
    config_path = os.path.join(training_rootdir,ckpt,'wandb/latest-run/files/config.yaml')

    with open(config_path) as stream:
        try:
            opt = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    
    keys = ["name","phase","gpu_ids","path","datasets","model","train","distributed"]
    return {k: opt[k]['value'] for k in keys}

# %%
opt = load_config(ckpt)
opt['path']['resume_state'] = model_checkpoint_fpath_prefix()
print(opt['path']['resume_state'])

opt['model']['beta_schedule']['val']['n_timestep'] = num_timesteps
opt['datasets']['val']['datapath'] = {
 'ch0': '/group/jug/ashesh/data/diffsplit_hagen/test/test_actin-60x-noise2-highsnr.tif',
 'ch1': '/group/jug/ashesh/data/diffsplit_hagen/test/test_mito-60x-noise2-highsnr.tif'
 }
# Out:
# /group/jug/ashesh/training/diffsplit/2410/Hagen-joint_indi-l1/27/checkpoint/I520000_E1625

# %%
# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/18/checkpoint/I350000_E1094'
# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/18/checkpoint/I380000_E1188'
# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/18/checkpoint/I360000_E1125'


# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/16/checkpoint/I350000_E1094'

# %%
if 'patch_size' not in opt['datasets']:
    opt['datasets']['patch_size']  = opt['datasets']['train']['patch_size']

if 'max_qval' not in opt['datasets']:
    opt['datasets']['max_qval']  = 0.98

if 'uncorrelated_channels' not in opt['datasets']['train']:
    opt['datasets']['train']['uncorrelated_channels']  = False

# %%
import torch
import data as Data
import model as Model
from data.split_dataset import SplitDataset, DataLocation
from split import get_datasets
import os


# data
train_set, val_set = get_datasets(opt, tiled_pred=True)

# model
diffusion = Model.create_model(opt)
diffusion.set_new_noise_schedule(opt['model']['beta_schedule'][opt['phase']], schedule_phase=opt['phase'])

# load checkpoint
diffusion.load_network()
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.18 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations
# HARDCODED upperclip to 1993. Disable it if not needed !!!
# Computing mean and std for normalization
# [SplitDataset] Data: 80x2x(2048, 2048) Patch:512 Random:1 Aug:True Q:0.995 UpperClip:0Uncor:False
# HARDCODED upperclip to 1993. Disable it if not needed !!!
# [TilingDataset] Data: 10x2x(2048, 2048) Patch:512 Random:0 Aug:False Q:0.995 UpperClip:0Uncor:False
# INFO:base:Initialization method [orthogonal]
# [IndiCustomT]: Sampling mode: linear_indi, Noise mode: brownian
# [IndiCustomT]: Sampling mode: linear_indi, Noise mode: brownian
# [JointIndi]: w_input_loss: 0.1
# INFO:base:Loading pretrained model for G [/group/jug/ashesh/training/diffsplit/2410/Hagen-joint_indi-l1/27/checkpoint/I520000_E1625] ...
# INFO:base:Model [DDPM] is created.
# INFO:base:Loading pretrained model for G [/group/jug/ashesh/training/diffsplit/2410/Hagen-joint_indi-l1/27/checkpoint/I520000_E1625] ...

# %%
import matplotlib.pyplot as plt

data= train_set[0]
inp = data['input']
target = data['target']
inp = inp.transpose(1,2,0)
target = target.transpose(1,2,0)
inp = (1 + inp) / 2
target = (1 + target) / 2
is_rgb = inp.shape[-1]%3 == 0
nC = 3 if is_rgb else 1
print(inp.min(), inp.max(), target[:nC].min(), target[:nC].max(), target[nC:].min(), target[nC:].max())
_,ax = plt.subplots(figsize=(8,2),ncols=4)
ax[0].imshow(inp)
ax[1].imshow(target[...,:nC])
if target.shape[-1] > nC:
    ax[2].imshow(target[...,nC:])
    ax[3].imshow((target[...,:nC] + target[...,nC:])/2)
# Out:
# 0.065775216 1.1933502 0.051680893 0.8236808 0.03512293 1.2824968

# %%
import numpy as np
import random

def fix_seeds():
    torch.manual_seed(0)
    torch.cuda.manual_seed(0)
    np.random.seed(0)
    random.seed(0)
    torch.backends.cudnn.deterministic = True

fix_seeds()

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

norm_dict = val_set.get_normalization_dict()
nimgs = 6
dloader = torch.utils.data.DataLoader(
            val_set,
            batch_size=nimgs,
            shuffle=True,
            num_workers=0,
            pin_memory=True)
for data in dloader:
    break

diffusion_data = {'input': data['target'].mean(dim=1,keepdims=True).cuda(), 'target': data['target'].cuda()}

# %%
def get_prediction(data_dict):
    input_unnorm, target_unnorm, pred_unnorm = get_prediction_raw(data_dict)
    target_unnorm = target_unnorm.transpose(0,2,3,1)
    pred_unnorm = pred_unnorm.transpose(0,2,3,1)
    input_unnorm = input_unnorm.transpose(0,2,3,1)
    return input_unnorm, target_unnorm, pred_unnorm

def get_prediction_raw(data_dict):
    assert 'input' in data_dict
    assert 'target' in data_dict
    assert len(data_dict['input'].shape) == 4
    assert len(data_dict['target'].shape) == 4
    diffusion.feed_data(data_dict)
    diffusion.test(continous=True, clip_denoised=False)
    visuals = diffusion.get_current_visuals()
    # input, target, prediction = unnormalize_data(visuals,train_set.get_normalization_dict())
    input = visuals['input'].cpu().numpy()
    target = visuals['target'].cpu().numpy()
    prediction = visuals['prediction'].cpu().numpy()

    # unnormalize 
    pred_unnorm = prediction * norm_dict['std_target'][None] + norm_dict['mean_target'][None]
    target_unnorm = target * norm_dict['std_target'][None] + norm_dict['mean_target'][None]
    input_unnorm = input * norm_dict['std_input'] + norm_dict['mean_input']


    if opt['datasets']['train']['name'] == 'cifar10':
        pred_unnorm[pred_unnorm<0] = 0
        pred_unnorm[pred_unnorm>255] = 255
        pred_unnorm = pred_unnorm.astype(np.uint8)
        target_unnorm = target_unnorm.astype(np.uint8)
        input_unnorm = input_unnorm.astype(np.uint16)

    return input_unnorm, target_unnorm, pred_unnorm

# %%
diffusion.set_new_noise_schedule(
    opt['model']['beta_schedule']['val'], schedule_phase='val')

# %%
img_idx = 2
tmp_data = {'input': diffusion_data['input'][img_idx:img_idx+1].cuda(), 'target': diffusion_data['target'][img_idx:img_idx+1].cuda()}
diffusion.feed_data(tmp_data)
diffusion.test(continous=True, clip_denoised=False)
visuals = diffusion.get_current_visuals()
# input, target, prediction = unnormalize_data(visuals,train_set.get_normalization_dict())
input = visuals['input'].cpu().numpy()
target = visuals['target'].cpu().numpy()
prediction = visuals['prediction'].cpu().numpy()
# Out:
# sampling loop time step: 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.94it/s]

# %%
import numpy as np
np.arange(0.5,0 -0.1/2, -0.1)
# Out:
# array([5.00000000e-01, 4.00000000e-01, 3.00000000e-01, 2.00000000e-01,
#        1.00000000e-01, 1.11022302e-16])

# %%
_,ax = plt.subplots(figsize=(8,4),ncols=2)
ax[0].imshow(prediction[-1,0])
ax[1].imshow(prediction[-1,1])

# %%
diffusion.set_new_noise_schedule(
    opt['model']['beta_schedule']['val'], schedule_phase='val')

target_arr = []
pred_arr = []
input_arr = []
for img_idx in range(nimgs):
    tmp_data = {'input':  diffusion_data['target'][img_idx:img_idx+1].mean(dim=1,keepdims=True).cuda(), 
                'target': diffusion_data['target'][img_idx:img_idx+1].cuda()}
    input_unnorm, target_unnorm, pred_unnorm = get_prediction(tmp_data)
    target_arr.append(target_unnorm)
    pred_arr.append(pred_unnorm[None])
    input_arr.append(input_unnorm)

inputs = np.concatenate(input_arr, axis=0)
targets = np.concatenate(target_arr, axis=0)
predictions = np.concatenate(pred_arr, axis=0)
# Out:
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.25it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.18it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.59it/s]
# sampling loop time step:   0%|          | 0/1 [00:00<?, ?it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.69it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]

# %%
predictions.shape
# Out:
# (6, 2, 512, 512, 2)

# %%
from disentangle.analysis.plot_utils import clean_ax
ncols = predictions.shape[1] + 1
assert nimgs % 2 == 0
nrows = 2*nimgs
dfac = 1
# rgb = target_unnorm.shape[-1]
_,ax = plt.subplots(figsize=(ncols*1*2,nrows*1//2), ncols=ncols*2, nrows=nrows//2)
ax = ax.reshape(nrows,ncols)
for img_idx in range(nimgs):
    for i in range(predictions.shape[1]):
        ax[0+img_idx*2,i].imshow(predictions[img_idx,i,::dfac,::dfac,:nC])
        ax[1+img_idx*2,i].imshow(predictions[img_idx,i,::dfac,::dfac,nC:])

    ax[0+img_idx*2,-1].imshow(targets[img_idx,::dfac,::dfac,:nC])
    ax[1+img_idx*2,-1].imshow(targets[img_idx,::dfac,::dfac,nC:])

ax[0,-1].set_title('GT Ch0')
ax[0,0].set_title('Input')
ax[0,-2].set_title('Pred Ch0')

ax[1,-1].set_title('GT Ch1')
ax[1,0].set_title('Input')
ax[1,-2].set_title('Pred Ch1')

clean_ax(ax)

# %%
import matplotlib.pyplot as plt 
from disentangle.analysis.plot_utils import clean_ax
img_idx = 2
pred_tmp = predictions[img_idx,-1]
target_tmp = targets[img_idx]
input_tmp = inputs[img_idx]
rgb_ch = target_tmp.shape[-1]

_,ax = plt.subplots(figsize=(9,6),ncols=3,nrows=2)
ax[0,0].set_title('Input', fontsize=15)
ax[1,0].axis('off')



ax[0,1].set_title('Channel 0', fontsize=15)
ax[0,2].set_title('Channel 1', fontsize=15)
ax[0,2].set_ylabel('Prediction', fontsize=15)
ax[1,2].set_ylabel('Target', fontsize=15)
ax[0,2].yaxis.set_label_position("right")
ax[1,2].yaxis.set_label_position("right")


ax[0,0].imshow(input_tmp)
ax[0,1].imshow(pred_tmp[...,:rgb_ch//2])
ax[1,1].imshow(target_tmp[...,:rgb_ch//2])

ax[0,2].imshow(pred_tmp[...,rgb_ch//2:])
ax[1,2].imshow(target_tmp[...,rgb_ch//2:])
clean_ax(ax)
# remove the space between the subplots
plt.subplots_adjust(wspace=0.02, hspace=0.02)

# %%
import seaborn as sns
show_hist = False
if show_hist:
    ncols = predictions.shape[-1]
    _,ax = plt.subplots(figsize=(3*ncols,3),ncols=ncols)
    for ch_idx in range(ncols):
        sns.histplot(targets[:,...,ch_idx].reshape(-1,), label='target',ax=ax[ch_idx])
        sns.histplot(predictions[:,-1,...,ch_idx].reshape(-1,), label='prediction', ax=ax[ch_idx])
    plt.legend()
    plt.tight_layout()

# %% [markdown]
# ## Metrics

# %%
from core.psnr import PSNR
from collections import defaultdict
from tqdm import tqdm

psnr_dict = defaultdict(list)
all_predictions = []
all_targets = []
for i in tqdm(range(len(val_set))):
    data = val_set[i]
    diffusion_data = {'input': torch.Tensor(data['target'].mean(axis=0, keepdims=True))[None].cuda(), 
                      'target': torch.Tensor(data['target'][None]).cuda()
                      }
    input_unnorm, target_unnorm, pred_unnorm = get_prediction_raw(diffusion_data);
    all_predictions.append(pred_unnorm[-1:].astype(np.float32))
    all_targets.append(target_unnorm)
    
    ch0_psnr = torch.mean(PSNR(pred_unnorm[-1,...,:nC].transpose(2,0,1), target_unnorm[0,...,:nC].transpose(2,0,1))).item()
    ch1_psnr = torch.mean(PSNR(pred_unnorm[-1,...,nC:].transpose(2,0,1), target_unnorm[0,...,nC:].transpose(2,0,1))).item()
    psnr_dict['ch0'].append(ch0_psnr)
    psnr_dict['ch1'].append(ch1_psnr)
# Out:
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.12it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.50it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.31it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.36it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.36it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.38it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.44it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.59it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.69it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.50it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.36it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.83it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.81it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.04it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.12it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.87it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.36it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 41.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.01it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.99it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.36it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.50it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.01it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.13it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.59it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.12it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.43it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.98it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.95it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.50it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.69it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.06it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.04it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.46it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.87it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.82it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.06it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.31it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.87it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.96it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.96it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.71it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.38it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.09it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.69it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.71it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.81it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.95it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.83it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.02it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.59it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.99it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.18it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.86it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.04it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.82it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.07it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.69it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.71it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.38it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.43it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 31.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 19.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 26.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.95it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.82it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.40it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.83it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.40it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.02it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.04it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.01it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.04it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.06it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.46it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.99it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.43it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.95it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.18it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.67it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.07it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.12it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.40it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 38.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.67it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.61it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.83it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 41.95it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.87it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.43it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.61it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.59it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.61it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.96it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.59it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.01it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.71it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.71it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.43it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.46it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.71it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.18it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.44it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.44it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.61it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.46it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 38.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.50it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.38it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.82it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.86it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.95it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.50it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.07it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.01it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.09it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.01it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.13it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.25it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.25it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.50it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.69it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.31it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.67it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.44it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.44it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.40it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.43it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.99it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.09it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.04it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.82it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.38it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.40it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.06it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.61it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.02it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.68it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.43it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.67it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.98it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.46it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.31it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.83it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.09it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 41.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.46it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.18it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.12it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.95it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.06it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.04it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.84it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.86it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.96it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.47it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.66it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.40it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.21it/s]
# ...
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.82it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.96it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 38.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.74it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.16it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.69it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 41.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.34it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.81it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.75it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.25it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.67it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.64it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.60it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.86it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.07it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.21it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.94it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.09it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.71it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.13it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.90it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.29it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.48it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.03it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.02it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.01it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.35it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.33it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.82it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.36it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.11it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.39it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.92it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.20it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.52it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.30it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.07it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.83it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.05it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.96it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.08it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 42.18it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.54it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.99it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.99it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.49it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.31it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.87it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.13it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.83it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.02it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.91it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.15it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.23it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.37it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.55it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.26it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.41it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.25it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.70it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.06it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.18it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.53it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.57it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.59it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.96it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.77it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.79it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.24it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.40it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.42it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.00it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.76it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.89it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.10it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.46it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.07it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.99it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.59it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.63it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.07it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 41.19it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.56it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.93it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.22it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.12it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.28it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.78it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.65it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.17it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.51it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.45it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.85it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.25it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 44.97it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 48.32it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.88it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.14it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 46.80it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.73it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.72it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 43.76it/s]
# 100%|██████████| 490/490 [00:31<00:00, 15.46it/s]

# %%
import gc; gc.collect()
# Out:
# 83071

# %%
predictions = np.concatenate(all_predictions, axis=0)
predictions.shape
# Out:
# (490, 2, 512, 512)

# %%
from data.tile_stitcher import stitch_predictions
pred_stitched = stitch_predictions(predictions, val_set.tile_manager)
# Out:
# [10, 2048, 2048, 2]

# %%
max_val = None
# ch0 = np.stack(train_set._data_dict[0])
# ch1 = np.stack(train_set._data_dict[1])
# target_stitched_train = np.stack([ch0,ch1], axis=-1)
# max_val = np.quantile(target_stitched_train,0.995)

# %%
ch0 = np.stack(val_set._data_dict[0])
ch1 = np.stack(val_set._data_dict[1])
target_stitched = np.stack([ch0,ch1], axis=-1)
if max_val is not None:
    target_stitched[target_stitched>max_val] = max_val
    pred_stitched[pred_stitched>max_val] = max_val
target_stitched.shape
# Out:
# (10, 2048, 2048, 2)

# %%
_,ax = plt.subplots(figsize=(12,8),ncols=3,nrows=2)
img_idx = 0
ax[0,0].imshow(target_stitched[img_idx,...,:nC] + target_stitched[img_idx,...,nC:])
ax[0,1].imshow(pred_stitched[img_idx,...,:nC])
ax[0,2].imshow(pred_stitched[img_idx,...,nC:])
ax[1,1].imshow(target_stitched[img_idx,...,:nC])
ax[1,2].imshow(target_stitched[img_idx,...,nC:])

ax[0,0].set_title('Input', fontsize=15)
ax[0,1].set_title('Channel 0', fontsize=15)
ax[0,2].set_title('Channel 1', fontsize=15)
ax[0,2].set_ylabel('Prediction', fontsize=15)
ax[1,2].set_ylabel('Target', fontsize=15)
ax[0,2].yaxis.set_label_position("right")
ax[1,2].yaxis.set_label_position("right")

ax[1,0].axis('off')

# reduce the space between the subplots
plt.subplots_adjust(wspace=0.02, hspace=0.02)
clean_ax(ax)

# %%
from core.psnr import RangeInvariantPsnr
ch0psnr, ch1psnr = [RangeInvariantPsnr(target_stitched[...,i]*1.0, pred_stitched[...,i]) for i in range(2)]
msg_psnr = f'PSNR: N{num_timesteps} '
msg_psnr += f'Ch0: {ch0psnr.mean().item():.1f} +- {ch0psnr.std().item()/np.sqrt(len(ch0psnr)):.1f}\t'
msg_psnr += f'Ch1: {ch1psnr.mean().item():.1f} +- {ch1psnr.std().item()/np.sqrt(len(ch1psnr)):.1f}'
print(msg_psnr)
# Out:
# PSNR: N1 Ch0: 33.5 +- 0.8	Ch1: 36.0 +- 0.8

# %%
from collections import defaultdict
import lpips
loss_fn_vgg = lpips.LPIPS(net='alex').cuda()

def compute_lpips(target, pred):
    # NHWC -> NCHW
    target = target.transpose(0,3,1,2) # channel is  in the second dimension
    pred = pred.transpose(0,3,1,2)    
    output = defaultdict(list)
    for ch_idx in range(target.shape[1]):
        tar_tmp = target[:,ch_idx:ch_idx+1]
        pred_tmp = pred[:,ch_idx:ch_idx+1]
        tar_tmp = np.repeat(tar_tmp, 3, axis=1)
        pred_tmp = np.repeat(pred_tmp, 3, axis=1)
        max_val = tar_tmp.max()
        min_val = tar_tmp.min()
        tar_tmp  = 2*(tar_tmp - min_val)/(max_val - min_val) - 1
        pred_tmp = 2*(pred_tmp - min_val)/(max_val - min_val) - 1
        output[ch_idx] = [loss_fn_vgg(torch.Tensor(tar_tmp[i]).cuda(), torch.Tensor(pred_tmp[i]).cuda()).item() for i in range(tar_tmp.shape[0])]
    return output

lpips_dict = compute_lpips(target_stitched, pred_stitched)
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /localscratch/miniforge3/envs/usplit_vdi/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /localscratch/miniforge3/envs/usplit_vdi/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /localscratch/miniforge3/envs/usplit_vdi/lib/python3.9/site-packages/lpips/weights/v0.1/alex.pth

# %%
msg_lpips = f'LPIPS: N{num_timesteps} '
for k,v in lpips_dict.items():
    msg_lpips += f'Ch{k}: {np.mean(v):.3f}+-{np.std(v)/np.sqrt(len(v)):.3f}\t'

print(msg_lpips)
# Out:
# LPIPS: N1 Ch0: 0.038+-0.005	Ch1: 0.047+-0.005

# %%
print(msg_psnr)
print(msg_lpips)
# Out:
# PSNR: N1 Ch0: 33.5 +- 0.8	Ch1: 36.0 +- 0.8
# LPIPS: N1 Ch0: 0.038+-0.005	Ch1: 0.047+-0.005

# %%
# psnr = [34.0,33.5,33.1,32.6,32.9,32.7]
# lpips = [0.042,0.037, 0.037,0.039,0.035,0.035]

psnr = [34.4,34.1,33.9,33.7, 33.9, 33.4]
lpips = [0.067,0.057, 0.050, 0.048, 0.045, 0.050]

# %%
import matplotlib.pyplot as plt 
_,ax = plt.subplots(figsize=(3.5,3))
plt.scatter(lpips, psnr)
plt.xlabel('LPIPS')
plt.ylabel('PSNR')
# add a text for each point on the plot
text = [1,2,5,10,20,50]
for i, txt in enumerate(text):
    ax.annotate(f'N={txt}', (lpips[i]+0.0003, psnr[i]))

# ax.set_ylim(33,35)
# add grid 
plt.grid()
plt.tight_layout()

# %%
indi_model = diffusion.netG
dloader = torch.utils.data.DataLoader(
            val_set,
            batch_size=nimgs,
            shuffle=True,
            num_workers=0,
            pin_memory=True)
for data in dloader:
    break

# %%
mixing_t = 0.3
img_idx = 1
inp_indi0 = data['target'][img_idx:img_idx+1,:1]*(1-mixing_t) + data['target'][img_idx:img_idx+1,1:2]*mixing_t
inp_indi1 = data['target'][img_idx:img_idx+1,1:2]*(1-mixing_t) + data['target'][img_idx:img_idx+1,:1]*mixing_t
_,ax = plt.subplots(figsize=(8,4),ncols=2)
ax[0].imshow(inp_indi0[0,0].cpu())
ax[1].imshow(inp_indi1[0,0].cpu())

# %%
predicted_t = mixing_t

# %%
ch1 = indi_model.indi1.p_sample_loop(inp_indi0.cuda(), clip_denoised=True, continous=False, num_timesteps=1, t_float_start=predicted_t)
ch2 = indi_model.indi2.p_sample_loop(inp_indi1.cuda(), clip_denoised=True, continous=False, num_timesteps=1, t_float_start=predicted_t)
# Out:
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.27it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.84it/s]

# %%
_,ax = plt.subplots(figsize=(8,12),nrows=3,ncols=2)
ax[0,0].imshow(inp_indi0[0,0])
ax[0,1].imshow(inp_indi1[0,0])
ax[1,0].imshow(ch1[0].cpu())
ax[1,1].imshow(ch2[0].cpu())

ax[2,0].imshow(data['target'][img_idx,0])
ax[2,1].imshow(data['target'][img_idx,1])

# %%
data['target'].shape
# Out:
# torch.Size([6, 2, 512, 512])
