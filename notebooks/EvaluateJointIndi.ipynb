# %%
import sys
sys.path.append('..')

from data.tile_stitcher import stitch_predictions

# %%
# ckpt = '2410/Hagen-joint_indi-l1/36'
ckpt  = '2410/Hagen-joint_indi-l1/36'
training_rootdir = '/group/jug/ashesh/training/diffsplit/'
num_timesteps = 1



ckpt = ckpt.strip('/').strip(' ')
ckpt
# Out:
# '2410/Hagen-joint_indi-l1/36'

# %%
import yaml
import os
import glob

def model_checkpoint_fpath(fname=None):
    ckpt_dir = os.path.join(training_rootdir, ckpt, 'checkpoint')
    if fname is not None:
        return os.path.join(training_rootdir, ckpt, fname)
    else:
        list_of_files = glob.glob(ckpt_dir +'/*_gen.pth') # * means all if need specific format then *.csv
        latest_file = max(list_of_files, key=os.path.getctime)
        fname = latest_file
        return os.path.join(ckpt_dir,latest_file)

def model_checkpoint_fpath_prefix(fname=None):
    fpath = model_checkpoint_fpath(fname)
    suffix = '_gen.pth'
    assert fpath.endswith(suffix)
    return fpath[:-len(suffix)]

def load_config(ckpt):
    config_path = os.path.join(training_rootdir,ckpt,'wandb/latest-run/files/config.yaml')

    with open(config_path) as stream:
        try:
            opt = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    
    keys = ["name","phase","gpu_ids","path","datasets","model","train", "distributed"]
    output = {}
    for k in keys:
        if k in opt:
            output[k] = opt[k]['value']
    return output

# %%
opt = load_config(ckpt)
opt['path']['resume_state'] = model_checkpoint_fpath_prefix()
print(opt['path']['resume_state'])

opt['model']['beta_schedule']['val']['n_timestep'] = num_timesteps
opt['datasets']['val']['datapath'] = {
 'ch0': '/group/jug/ashesh/data/diffsplit_hagen/test/test_actin-60x-noise2-highsnr.tif',
 'ch1': '/group/jug/ashesh/data/diffsplit_hagen/test/test_mito-60x-noise2-highsnr.tif'
 }
# Out:
# /group/jug/ashesh/training/diffsplit/2410/Hagen-joint_indi-l1/36/checkpoint/I860000_E2688

# %%
# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/18/checkpoint/I350000_E1094'
# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/18/checkpoint/I380000_E1188'
# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/18/checkpoint/I360000_E1125'


# opt['path']['resume_state'] = '/group/jug/ashesh/training/diffsplit/2409/Hagen-indi-l1/16/checkpoint/I350000_E1094'

# %%
if 'patch_size' not in opt['datasets']:
    opt['datasets']['patch_size']  = opt['datasets']['train']['patch_size']

if 'max_qval' not in opt['datasets']:
    opt['datasets']['max_qval']  = 0.98

if 'uncorrelated_channels' not in opt['datasets']['train']:
    opt['datasets']['train']['uncorrelated_channels']  = False

# %%
import torch
import data as Data
import model as Model
from data.split_dataset import SplitDataset, DataLocation
from split import get_datasets
import os


# data
train_set, val_set = get_datasets(opt, tiled_pred=True)

# model
diffusion = Model.create_model(opt)
diffusion.set_new_noise_schedule(opt['model']['beta_schedule'][opt['phase']], schedule_phase=opt['phase'])

# load checkpoint
diffusion.load_network()
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.21 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations
# HARDCODED upperclip to 1993. Disable it if not needed !!!
# Computing mean and std for normalization
# INFO:base:Initialization method [orthogonal]
# [SplitDataset] Data: 80x2x(2048, 2048) Patch:512 Random:1 Aug:True Q:0.995 UpperClip:0Uncor:False InpFrmNormTar
# HARDCODED upperclip to 1993. Disable it if not needed !!!
# [TilingDataset] Data: 10x2x(2048, 2048) Patch:512 Random:0 Aug:False Q:0.995 UpperClip:0Uncor:False InpFrmNormTar
# [IndiCustomT]: Sampling mode: linear_indi, Noise mode: gaussian
# [IndiCustomT]: Sampling mode: linear_indi, Noise mode: gaussian
# [JointIndi]: w_input_loss: 0.1
# INFO:base:Loading pretrained model for G [/group/jug/ashesh/training/diffsplit/2410/Hagen-joint_indi-l1/36/checkpoint/I860000_E2688] ...
# INFO:base:Model [DDPM] is created.
# INFO:base:Loading pretrained model for G [/group/jug/ashesh/training/diffsplit/2410/Hagen-joint_indi-l1/36/checkpoint/I860000_E2688] ...

# %%
from collections import defaultdict
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd


w_list = np.arange(0,1, 0.2)
stats = {w: defaultdict(list) for w in w_list}
for w in w_list:
    for i in range(len(val_set)):
        data_dict = val_set[i]
        inp = (1-w) * data_dict['target'][:1] + w * data_dict['target'][1:]
        stats[w]['min'].append(inp.min())
        stats[w]['max'].append(inp.max())
        stats[w]['mean'].append(inp.mean())
        stats[w]['std'].append(inp.std())
    

_,ax = plt.subplots(figsize=(18,3),ncols=4)
for w in w_list:
    ax[0].plot(pd.Series(stats[w]['min']).rolling(20).mean(), label=f't={w:.1f}')
    ax[1].plot(pd.Series(stats[w]['max']).rolling(20).mean(), label=f't={w:.1f}')
    ax[2].plot(pd.Series(stats[w]['mean']).rolling(20).mean(), label=f't={w:.1f}')
    ax[3].plot(pd.Series(stats[w]['std']).rolling(20).mean(), label=f't={w:.1f}')
ax[0].legend()
ax[0].set_title('min')
ax[1].set_title('max')
ax[2].set_title('mean')
ax[3].set_title('std')
# Out:
# Text(0.5, 1.0, 'std')

# %%
import matplotlib.pyplot as plt

data= train_set[0]
inp = data['input']
target = data['target']
inp = inp.transpose(1,2,0)
target = target.transpose(1,2,0)
inp = (1 + inp) / 2
target = (1 + target) / 2
is_rgb = inp.shape[-1]%3 == 0
nC = 3 if is_rgb else 1
print(inp.min(), inp.max(), target[:nC].min(), target[:nC].max(), target[nC:].min(), target[nC:].max())
_,ax = plt.subplots(figsize=(8,2),ncols=4)
ax[0].imshow(inp)
ax[1].imshow(target[...,:nC])
if target.shape[-1] > nC:
    ax[2].imshow(target[...,nC:])
    ax[3].imshow((target[...,:nC] + target[...,nC:])/2)
# Out:
# -0.4017914 0.3594505 0.050175607 0.42047167 0.03462118 0.7310587

# %%
import numpy as np
import random

def fix_seeds():
    torch.manual_seed(0)
    torch.cuda.manual_seed(0)
    np.random.seed(0)
    random.seed(0)
    torch.backends.cudnn.deterministic = True

fix_seeds()

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

norm_dict = val_set.get_normalization_dict()
nimgs = 6
dloader = torch.utils.data.DataLoader(
            val_set,
            batch_size=nimgs,
            shuffle=True,
            num_workers=0,
            pin_memory=True)
for data in dloader:
    break

diffusion_data = {'input': data['target'].mean(dim=1,keepdims=True).cuda(), 'target': data['target'].cuda()}

# %%
def get_prediction(data_dict):
    input_unnorm, target_unnorm, pred_unnorm = get_prediction_raw(data_dict)
    target_unnorm = target_unnorm.transpose(0,2,3,1)
    pred_unnorm = pred_unnorm.transpose(0,2,3,1)
    input_unnorm = input_unnorm.transpose(0,2,3,1)
    return input_unnorm, target_unnorm, pred_unnorm

def get_prediction_raw(data_dict):
    assert 'input' in data_dict
    assert 'target' in data_dict
    assert len(data_dict['input'].shape) == 4
    assert len(data_dict['target'].shape) == 4
    diffusion.feed_data(data_dict)
    diffusion.test(continuous=True, clip_denoised=False)
    visuals = diffusion.get_current_visuals()
    # input, target, prediction = unnormalize_data(visuals,train_set.get_normalization_dict())
    input = visuals['input'].cpu().numpy()
    target = visuals['target'].cpu().numpy()
    prediction = visuals['prediction'].cpu().numpy()

    # unnormalize 
    pred_unnorm = prediction * norm_dict['std_target'][None] + norm_dict['mean_target'][None]
    target_unnorm = target * norm_dict['std_target'][None] + norm_dict['mean_target'][None]
    input_unnorm = input * norm_dict['std_input'] + norm_dict['mean_input']


    if opt['datasets']['train']['name'] == 'cifar10':
        pred_unnorm[pred_unnorm<0] = 0
        pred_unnorm[pred_unnorm>255] = 255
        pred_unnorm = pred_unnorm.astype(np.uint8)
        target_unnorm = target_unnorm.astype(np.uint8)
        input_unnorm = input_unnorm.astype(np.uint16)

    return input_unnorm, target_unnorm, pred_unnorm

# %%
diffusion.set_new_noise_schedule(
    opt['model']['beta_schedule']['val'], schedule_phase='val')

# %%
img_idx = 2
tmp_data = {'input': diffusion_data['input'][img_idx:img_idx+1].cuda(), 'target': diffusion_data['target'][img_idx:img_idx+1].cuda()}
diffusion.feed_data(tmp_data)
diffusion.test(continuous=True, clip_denoised=False)
visuals = diffusion.get_current_visuals()
# input, target, prediction = unnormalize_data(visuals,train_set.get_normalization_dict())
input = visuals['input'].cpu().numpy()
target = visuals['target'].cpu().numpy()
prediction = visuals['prediction'].cpu().numpy()
# Out:
# inference time step: 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.26it/s]

# %%
prediction.shape
# Out:
# (2, 2, 512, 512)

# %%
_,ax = plt.subplots(figsize=(8,4),ncols=2)
ax[0].imshow(prediction[-1,0])
ax[1].imshow(prediction[-1,1])

# %%
break here
# Out:
#   Cell In[17], line 1
#     break here
#           ^
# SyntaxError: invalid syntax

# %%
diffusion.set_new_noise_schedule(
    opt['model']['beta_schedule']['val'], schedule_phase='val')

target_arr = []
pred_arr = []
input_arr = []
for img_idx in range(nimgs):
    tmp_data = {'input':  diffusion_data['target'][img_idx:img_idx+1].mean(dim=1,keepdims=True).cuda(), 
                'target': diffusion_data['target'][img_idx:img_idx+1].cuda()}
    input_unnorm, target_unnorm, pred_unnorm = get_prediction(tmp_data)
    target_arr.append(target_unnorm)
    pred_arr.append(pred_unnorm[None])
    input_arr.append(input_unnorm)

inputs = np.concatenate(input_arr, axis=0)
targets = np.concatenate(target_arr, axis=0)
predictions = np.concatenate(pred_arr, axis=0)
# Out:
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.22it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.26it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.07it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 49.21it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.23it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.33it/s]

# %%
predictions.shape
# Out:
# (6, 6, 512, 512, 2)

# %%
from disentangle.analysis.plot_utils import clean_ax
ncols = predictions.shape[1] + 1
assert nimgs % 2 == 0
nrows = 2*nimgs
dfac = 1
# rgb = target_unnorm.shape[-1]
_,ax = plt.subplots(figsize=(ncols*1*2,nrows*1//2), ncols=ncols*2, nrows=nrows//2)
ax = ax.reshape(nrows,ncols)
for img_idx in range(nimgs):
    for i in range(predictions.shape[1]):
        ax[0+img_idx*2,i].imshow(predictions[img_idx,i,::dfac,::dfac,:nC])
        ax[1+img_idx*2,i].imshow(predictions[img_idx,i,::dfac,::dfac,nC:])

    ax[0+img_idx*2,-1].imshow(targets[img_idx,::dfac,::dfac,:nC])
    ax[1+img_idx*2,-1].imshow(targets[img_idx,::dfac,::dfac,nC:])

ax[0,-1].set_title('GT Ch0')
ax[0,0].set_title('Input')
ax[0,-2].set_title('Pred Ch0')

ax[1,-1].set_title('GT Ch1')
ax[1,0].set_title('Input')
ax[1,-2].set_title('Pred Ch1')

clean_ax(ax)

# %%
import matplotlib.pyplot as plt 
from disentangle.analysis.plot_utils import clean_ax
img_idx = 2
pred_tmp = predictions[img_idx,-1]
target_tmp = targets[img_idx]
input_tmp = inputs[img_idx]
rgb_ch = target_tmp.shape[-1]

_,ax = plt.subplots(figsize=(9,6),ncols=3,nrows=2)
ax[0,0].set_title('Input', fontsize=15)
ax[1,0].axis('off')



ax[0,1].set_title('Channel 0', fontsize=15)
ax[0,2].set_title('Channel 1', fontsize=15)
ax[0,2].set_ylabel('Prediction', fontsize=15)
ax[1,2].set_ylabel('Target', fontsize=15)
ax[0,2].yaxis.set_label_position("right")
ax[1,2].yaxis.set_label_position("right")


ax[0,0].imshow(input_tmp)
ax[0,1].imshow(pred_tmp[...,:rgb_ch//2])
ax[1,1].imshow(target_tmp[...,:rgb_ch//2])

ax[0,2].imshow(pred_tmp[...,rgb_ch//2:])
ax[1,2].imshow(target_tmp[...,rgb_ch//2:])
clean_ax(ax)
# remove the space between the subplots
plt.subplots_adjust(wspace=0.02, hspace=0.02)

# %%
import seaborn as sns
show_hist = False
if show_hist:
    ncols = predictions.shape[-1]
    _,ax = plt.subplots(figsize=(3*ncols,3),ncols=ncols)
    for ch_idx in range(ncols):
        sns.histplot(targets[:,...,ch_idx].reshape(-1,), label='target',ax=ax[ch_idx])
        sns.histplot(predictions[:,-1,...,ch_idx].reshape(-1,), label='prediction', ax=ax[ch_idx])
    plt.legend()
    plt.tight_layout()

# %% [markdown]
# ## Evaluation on whole dataset

# %%
from core.psnr import PSNR
from collections import defaultdict
from tqdm import tqdm

psnr_dict = defaultdict(list)
all_predictions = []
all_targets = []
for i in tqdm(range(len(val_set))):
    data = val_set[i]
    diffusion_data = {'input': torch.Tensor(data['target'].mean(axis=0, keepdims=True))[None].cuda(), 
                      'target': torch.Tensor(data['target'][None]).cuda()
                      }
    input_unnorm, target_unnorm, pred_unnorm = get_prediction_raw(diffusion_data)
    all_predictions.append(pred_unnorm[-1:].astype(np.float32))
    all_targets.append(target_unnorm)
    
    ch0_psnr = torch.mean(PSNR(pred_unnorm[-1,...,:nC].transpose(2,0,1), target_unnorm[0,...,:nC].transpose(2,0,1))).item()
    ch1_psnr = torch.mean(PSNR(pred_unnorm[-1,...,nC:].transpose(2,0,1), target_unnorm[0,...,nC:].transpose(2,0,1))).item()
    psnr_dict['ch0'].append(ch0_psnr)
    psnr_dict['ch1'].append(ch1_psnr)
# Out:
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.88it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.54it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.09it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.69it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.02it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.07it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.99it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.81it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 57.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.47it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.88it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.56it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.15it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 57.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.16it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.03it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.33it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.38it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 58.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.38it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.20it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 58.99it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.54it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 71.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.03it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.54it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.35it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.15it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.38it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 54.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.69it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.38it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.13it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 58.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.48it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.38it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.07it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.20it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.58it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.02it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.29it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 58.48it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.87it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.81it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.07it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.33it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.63it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.99it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.88it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.48it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.02it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.13it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.88it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.99it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.38it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.54it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.03it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.29it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.74it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.30it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.16it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.81it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.33it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 54.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.63it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.13it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.16it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.09it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.35it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 58.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.33it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.63it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.48it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.09it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.99it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.13it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 49.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.74it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.30it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.56it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.03it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.87it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.29it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.07it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.41it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.03it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.15it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.16it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.29it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.56it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.09it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.69it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.54it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.09it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 20.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.88it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.58it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.69it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.15it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 58.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.99it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.58it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.47it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.13it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.58it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.35it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.88it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.60it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.87it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 55.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.58it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.30it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 53.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.09it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 58.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.87it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.48it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.07it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.20it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.29it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.47it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.44it/s]
# ...
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.31it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.47it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.16it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.35it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.83it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.03it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.30it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.20it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 56.13it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.08it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.47it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.63it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 57.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.80it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.15it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.16it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.88it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.56it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.92it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.74it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.16it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.30it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.03it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.50it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.02it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.28it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.52it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.79it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.26it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.48it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.63it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.15it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.59it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.51it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.02it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.76it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.35it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.73it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.22it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.25it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.77it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.10it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.32it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.91it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.97it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.45it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.56it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.67it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.61it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.18it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.44it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.21it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.07it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.20it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.43it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.78it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.69it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.64it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.34it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.19it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.47it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.94it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.74it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.54it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.86it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.02it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.12it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.74it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.13it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.38it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 60.84it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.11it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.39it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.71it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.23it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.74it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.72it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.37it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 57.96it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.30it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 59.05it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.09it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.98it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 57.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.17it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.93it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.85it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.47it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.15it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.00it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.57it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 64.46it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.40it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.55it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.01it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.75it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 61.29it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.06it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.42it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 62.24it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.90it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 65.99it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.62it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 63.89it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 66.93it/s]
# 100%|██████████| 490/490 [00:30<00:00, 16.31it/s]

# %%
import gc; gc.collect()
# Out:
# 10301

# %%
predictions = np.concatenate(all_predictions, axis=0)
predictions.shape
# Out:
# (490, 2, 512, 512)

# %%
pred_stitched = stitch_predictions(predictions, val_set.tile_manager)
# Out:
# [10, 2048, 2048, 2]

# %%
max_val = None
# ch0 = np.stack(train_set._data_dict[0])
# ch1 = np.stack(train_set._data_dict[1])
# target_stitched_train = np.stack([ch0,ch1], axis=-1)
# max_val = np.quantile(target_stitched_train,0.995)

# %%
ch0 = np.stack(val_set._data_dict[0])
ch1 = np.stack(val_set._data_dict[1])
target_stitched = np.stack([ch0,ch1], axis=-1)
if max_val is not None:
    target_stitched[target_stitched>max_val] = max_val
    pred_stitched[pred_stitched>max_val] = max_val
target_stitched.shape
# Out:
# (10, 2048, 2048, 2)

# %%
_,ax = plt.subplots(figsize=(12,8),ncols=3,nrows=2)
img_idx = 0
ax[0,0].imshow(target_stitched[img_idx,...,:nC] + target_stitched[img_idx,...,nC:])
ax[0,1].imshow(pred_stitched[img_idx,...,:nC])
ax[0,2].imshow(pred_stitched[img_idx,...,nC:])
ax[1,1].imshow(target_stitched[img_idx,...,:nC])
ax[1,2].imshow(target_stitched[img_idx,...,nC:])

ax[0,0].set_title('Input', fontsize=15)
ax[0,1].set_title('Channel 0', fontsize=15)
ax[0,2].set_title('Channel 1', fontsize=15)
ax[0,2].set_ylabel('Prediction', fontsize=15)
ax[1,2].set_ylabel('Target', fontsize=15)
ax[0,2].yaxis.set_label_position("right")
ax[1,2].yaxis.set_label_position("right")

ax[1,0].axis('off')

# reduce the space between the subplots
plt.subplots_adjust(wspace=0.02, hspace=0.02)
clean_ax(ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 21
#      19 # reduce the space between the subplots
#      20 plt.subplots_adjust(wspace=0.02, hspace=0.02)
# ---> 21 clean_ax(ax)
#
# NameError: name 'clean_ax' is not defined

# %%
from core.psnr import RangeInvariantPsnr
ch0psnr, ch1psnr = [RangeInvariantPsnr(target_stitched[...,i]*1.0, pred_stitched[...,i]) for i in range(2)]
msg_psnr = f'PSNR: N{num_timesteps} '
msg_psnr += f'Ch0: {ch0psnr.mean().item():.1f} +- {ch0psnr.std().item()/np.sqrt(len(ch0psnr)):.1f}\t'
msg_psnr += f'Ch1: {ch1psnr.mean().item():.1f} +- {ch1psnr.std().item()/np.sqrt(len(ch1psnr)):.1f}'
print(msg_psnr)
# Out:
# PSNR: N1 Ch0: 33.8 +- 0.8	Ch1: 36.0 +- 0.8

# %%
from collections import defaultdict
import lpips
loss_fn_vgg = lpips.LPIPS(net='alex').cuda()

def compute_lpips(target, pred):
    # NHWC -> NCHW
    target = target.transpose(0,3,1,2) # channel is  in the second dimension
    pred = pred.transpose(0,3,1,2)    
    output = defaultdict(list)
    for ch_idx in range(target.shape[1]):
        tar_tmp = target[:,ch_idx:ch_idx+1]
        pred_tmp = pred[:,ch_idx:ch_idx+1]
        tar_tmp = np.repeat(tar_tmp, 3, axis=1)
        pred_tmp = np.repeat(pred_tmp, 3, axis=1)
        max_val = tar_tmp.max()
        min_val = tar_tmp.min()
        tar_tmp  = 2*(tar_tmp - min_val)/(max_val - min_val) - 1
        pred_tmp = 2*(pred_tmp - min_val)/(max_val - min_val) - 1
        output[ch_idx] = [loss_fn_vgg(torch.Tensor(tar_tmp[i]).cuda(), torch.Tensor(pred_tmp[i]).cuda()).item() for i in range(tar_tmp.shape[0])]
    return output

lpips_dict = compute_lpips(target_stitched, pred_stitched)
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /localscratch/miniforge3/envs/usplit_vdi/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /localscratch/miniforge3/envs/usplit_vdi/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /localscratch/miniforge3/envs/usplit_vdi/lib/python3.9/site-packages/lpips/weights/v0.1/alex.pth

# %%
msg_lpips = f'LPIPS: N{num_timesteps} '
for k,v in lpips_dict.items():
    msg_lpips += f'Ch{k}: {np.mean(v):.3f}+-{np.std(v)/np.sqrt(len(v)):.3f}\t'

print(msg_lpips)
# Out:
# LPIPS: N1 Ch0: 0.050+-0.005	Ch1: 0.059+-0.005

# %%
print(msg_psnr)
print(msg_lpips)
# Out:
# PSNR: N1 Ch0: 33.8 +- 0.8	Ch1: 36.0 +- 0.8
# LPIPS: N1 Ch0: 0.050+-0.005	Ch1: 0.059+-0.005

# %%
# PSNR: N5 Ch0: 32.2 +- 0.9	Ch1: 34.5 +- 0.6
# LPIPS: N5 Ch0: 0.042+-0.005	Ch1: 0.042+-0.004	

# PSNR: N1 Ch0: 33.8 +- 0.8	Ch1: 36.0 +- 0.8
# LPIPS: N1 Ch0: 0.050+-0.005	Ch1: 0.059+-0.005

# %%
import matplotlib.pyplot as plt 
_,ax = plt.subplots(figsize=(3.5,3))
plt.scatter(lpips, psnr)
plt.xlabel('LPIPS')
plt.ylabel('PSNR')
# add a text for each point on the plot
text = [1,2,5,10,20,50]
for i, txt in enumerate(text):
    ax.annotate(f'N={txt}', (lpips[i]+0.0003, psnr[i]))

# ax.set_ylim(33,35)
# add grid 
plt.grid()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 import matplotlib.pyplot as plt
#       2 _,ax = plt.subplots(figsize=(3.5,3))
# ----> 3 plt.scatter(lpips, psnr)
#       4 plt.xlabel('LPIPS')
#       5 plt.ylabel('PSNR')
#
# NameError: name 'psnr' is not defined

# %%
indi_model = diffusion.netG
dloader = torch.utils.data.DataLoader(
            val_set,
            batch_size=nimgs,
            shuffle=True,
            num_workers=0,
            pin_memory=True)
for data in dloader:
    break

# %%
mixing_t = 0.15
img_idx = 1
inp_indi0 = data['target'][img_idx:img_idx+1,:1]*(1-mixing_t) + data['target'][img_idx:img_idx+1,1:2]*mixing_t
inp_indi1 = data['target'][img_idx:img_idx+1,1:2]*(1-mixing_t) + data['target'][img_idx:img_idx+1,:1]*mixing_t
_,ax = plt.subplots(figsize=(8,4),ncols=2)
ax[0].imshow(inp_indi0[0,0].cpu())
ax[1].imshow(inp_indi1[0,0].cpu())

# %%
predicted_t = mixing_t

# %%
ch1 = indi_model.indi1.p_sample_loop(inp_indi0.cuda(), clip_denoised=True, continuous=False, num_timesteps=1, t_float_start=predicted_t)
ch2 = indi_model.indi2.p_sample_loop(inp_indi1.cuda(), clip_denoised=True, continuous=False, num_timesteps=1, t_float_start=predicted_t)
# Out:
# sampling loop time step:   0%|          | 0/1 [00:00<?, ?it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 45.31it/s]
# sampling loop time step: 100%|██████████| 1/1 [00:00<00:00, 47.69it/s]

# %%
from disentangle.analysis.plot_utils import clean_ax

_,ax = plt.subplots(figsize=(12,8),nrows=2,ncols=3)
ax = ax.T
ax[0,0].imshow(inp_indi0[0,0], cmap='gray')
ax[0,1].imshow(inp_indi1[0,0], cmap='gray')
ax[1,0].imshow(ch1[0].cpu(), cmap='gray')
ax[1,1].imshow(ch2[0].cpu(), cmap='gray')

ax[2,0].imshow(data['target'][img_idx,0], cmap='gray')
ax[2,1].imshow(data['target'][img_idx,1], cmap='gray')
clean_ax(ax)
# remove the space between the subplots
plt.subplots_adjust(wspace=0.02, hspace=0.02)
ax = ax.T
ax[0,0].set_title('Input', fontsize=15, )
ax[0,1].set_title('Prediction', fontsize=15, )
ax[0,2].set_title('Target', fontsize=15, )
ax[0,2].set_ylabel('Actin', fontsize=15, )
ax[1,2].set_ylabel('Mito', fontsize=15, )

ax[0,2].yaxis.set_label_position("right")
ax[1,2].yaxis.set_label_position("right")

# save the figure to file with 200 dpi
# plt.savefig(f'indi_prediction_{mixing_t}.png', dpi=200)

# %% [markdown]
# ## Using Classifier to predict the time.

# %%
from model.ddpm_modules.time_predictor import TimePredictor
from data.time_predictor_dataset import compute_input_normalization_dict
# for normalization
classifier_T = 100
input_normalization_dict = compute_input_normalization_dict(val_set._data_dict, classifier_T, val_set._mean_target, val_set._std_target)

def min_max_normalize(img, t_float):
    assert 0 <= t_float < 1
    t_int = int(t_float * classifier_T)
    t_min, t_max = input_normalization_dict[t_int]
    return 2*(img - t_min)/(t_max - t_min) -1

classifier_ckpt = '/group/jug/ashesh/training/diffsplit/2410/Hagen-UnetClassifier-l2/8'
opt = load_config(classifier_ckpt)
model_opt = opt['model']
model = TimePredictor(
    in_channel=model_opt['unet']['in_channel'],
    out_channel=model_opt['unet']['out_channel'],
    norm_groups=model_opt['unet']['norm_groups'],
    inner_channel=model_opt['unet']['inner_channel'],
    channel_mults=model_opt['unet']['channel_multiplier'],
    attn_res=model_opt['unet']['attn_res'],
    res_blocks=model_opt['unet']['res_blocks'],
    dropout=model_opt['unet']['dropout'],
    image_size=opt['datasets']['patch_size'],
    )
model = model.cuda()
# load checkpoint
model.load_state_dict(torch.load(os.path.join(classifier_ckpt,'best_time_predictor.pth')), strict=True)

def get_time_prediction_ch0(input_ch0):
    with torch.no_grad():
        pred_t_0 = model(input_ch0.cuda())
    pred_t_0 = 1 - pred_t_0
    return pred_t_0

def get_time_prediction_ch1(input_ch1):
    with torch.no_grad():
        pred_t_1 = model(input_ch1.cuda())
    return pred_t_1
# Out:
# 100%|██████████| 101/101 [00:13<00:00,  7.57it/s]

# %%
indi_model = diffusion.netG
dloader = torch.utils.data.DataLoader(
            val_set,
            batch_size=nimgs,
            shuffle=True,
            num_workers=0,
            pin_memory=True)
for data in dloader:
    break

# %%
mixing_t = 0.1
img_idx = 2
inp_indi0 = data['target'][:,:1]*(1-mixing_t) + data['target'][:,1:2]*mixing_t
inp_indi1 = data['target'][:,1:2]*(1-mixing_t) + data['target'][:,:1]*mixing_t

# %%
img_idx = 1
_,ax = plt.subplots(figsize=(8,4),ncols=2)
ax[0].imshow(inp_indi0[img_idx,0])
ax[1].imshow(inp_indi1[img_idx,0])

# %%
pred_ch1 = []
pred_ch2 = []
model.eval()
with torch.no_grad():
    pred_t_0 = get_time_prediction_ch0(min_max_normalize(inp_indi0, 1-mixing_t).cuda())
    pred_t_1 = get_time_prediction_ch1(min_max_normalize(inp_indi1, mixing_t).cuda())
    for batch_idx in range(len(inp_indi0)):
        ch1 = indi_model.indi1.inference(inp_indi0[batch_idx:batch_idx+1].cuda(), 
                                             continuous=False, num_timesteps=None, t_float_start=pred_t_0[batch_idx].item())
        pred_ch1.append(ch1.cpu().numpy())
        ch2 = indi_model.indi2.inference(inp_indi1[batch_idx:batch_idx+1].cuda(), 
                                             continuous=False, num_timesteps=1, t_float_start=pred_t_1[batch_idx].item())
        pred_ch2.append(ch2.cpu().numpy())
# Out:
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 67.65it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.49it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.04it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.68it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 71.27it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 68.82it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.70it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.14it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 71.36it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 70.95it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 69.53it/s]
# inference time step: 100%|██████████| 1/1 [00:00<00:00, 71.19it/s]

# %%
pred_ch2[0].shape
# Out:
# (1, 1, 512, 512)

# %%
from disentangle.analysis.plot_utils import clean_ax
img_idx = 0

_,ax = plt.subplots(figsize=(4,6),nrows=3,ncols=2)

ax[0,0].imshow(inp_indi0[img_idx,0], )
ax[0,1].imshow(inp_indi1[img_idx,0], )
ax[1,0].imshow(pred_ch1[img_idx][0,0], )
ax[1,1].imshow(pred_ch2[img_idx][0,0], )

ax[2,0].imshow(data['target'][img_idx,0], )
ax[2,1].imshow(data['target'][img_idx,1], )
clean_ax(ax)
# remove the space between the subplots
plt.subplots_adjust(wspace=0.02, hspace=0.02)
ax[0,0].set_ylabel('Input', fontsize=15, )
ax[1,0].set_ylabel('Prediction', fontsize=15, )
ax[2,0].set_ylabel('Target', fontsize=15, )
ax[0,0].set_title('Actin', fontsize=15, )
ax[0,1].set_title('Mito', fontsize=15, )

# ax[0,2].yaxis.set_label_position("right")
# ax[1,2].yaxis.set_label_position("right")

# save the figure to file with 200 dpi
# plt.savefig(f'indi_prediction_{mixing_t}.png', dpi=200)
# Out:
# Text(0.5, 1.0, 'Mito')

# %% [markdown]
# ## Qualitative Evaluation using the classifier.

# %% [markdown]
# Here, we want to see the performance of both indi1 and indi2 predictions. when the input has mostly channel 1, then indi1 will be more accurate. When the input has mostly channel 2, then indi2 will be more accurate.

# %%
import gc; gc.collect()
# Out:
# 60494

# %%
# mixing_t_ood = 0.1
# num_timesteps = 2
# data = val_set[4]
# inp_indi1 = data['target'][:1]*(1-mixing_t_ood) + data['target'][1:2]*mixing_t_ood
# inp_indi2 = data['target'][1:2]*(1-mixing_t_ood) + data['target'][:1]*mixing_t_ood
# inp_indi1 = torch.Tensor(inp_indi1[None]).cuda()
# inp_indi2 = torch.Tensor(inp_indi2[None]).cuda()
# with torch.no_grad():
#     pred_t_1 = [mixing_t_ood] # get_time_prediction_ch0(inp_indi1.cuda()).detach().cpu().numpy() #
#     pred_t_2 = [mixing_t_ood] # get_time_prediction_ch1(inp_indi2.cuda()).detach().cpu().numpy() #[mixing_t_ood] #
#     pred_ch0 = indi_model.inference(inp_indi1, continuous=False, num_timesteps=num_timesteps, t_float_start=pred_t_1[0])
#     pred_ch1 = indi_model.inference(inp_indi2, continuous=False, num_timesteps=num_timesteps, t_float_start=pred_t_2[0])

# _,ax = plt.subplots(figsize=(16,8),ncols=4,nrows=2)
# ax[0,0].imshow(inp_indi0[0,0].cpu())
# ax[1,0].imshow(inp_indi1[0,0].cpu())

# ax[0,1].imshow(pred_ch0[0,0].cpu().numpy())
# ax[1,1].imshow(pred_ch0[0,1].cpu().numpy())

# ax[0,2].imshow(pred_ch1[0,0].cpu().numpy())
# ax[1,2].imshow(pred_ch1[0,1].cpu().numpy())


# ax[0,3].imshow(data['target'][0])
# ax[1,3].imshow(data['target'][1])
# ax[0,0].set_title('Input', fontsize=15)
# ax[0,1].set_title('Indi0 Predictions', fontsize=15)
# ax[0,2].set_title('Indi1 Predictions', fontsize=15)
# ax[0,3].set_title('Target', fontsize=15)

# %% [markdown]
# ## Quantitative Evaluation using the classifier.
# Here, we also inspect the effect of MMSE count.

# %%
from core.psnr import PSNR
from collections import defaultdict
from tqdm import tqdm

mixing_t_ood = 0.5
num_timesteps = 5
psnr_dict_ood = defaultdict(list)
mmse_count = 5
all_targets_ood = []
all_inputs_ood = []
eps = 1e-6

pred_t_0_arr = []
pred_t_1_arr = []
all_mmse_predictions_ood = []
for mmse_idx in range(mmse_count):
    all_predictions_ood = []
    for i in tqdm(range(len(val_set))):
        data = val_set[i]
        inp_indi0 = data['target'][:1]*(1-mixing_t_ood) + data['target'][1:2]*mixing_t_ood
        inp_indi1 = data['target'][1:2]*(1-mixing_t_ood) + data['target'][:1]*mixing_t_ood
        all_inputs_ood.append(np.concatenate([inp_indi0, inp_indi1], axis=0)[None])
        inp_indi0 = torch.Tensor(inp_indi0[None]).cuda()
        inp_indi1 = torch.Tensor(inp_indi1[None]).cuda()
        pred_t_0 = [mixing_t_ood] #get_time_prediction_ch0(min_max_normalize(inp_indi0, 1-mixing_t_ood).cuda()).detach().cpu().numpy() #[mixing_t_ood] #
        pred_t_1 = [mixing_t_ood] #get_time_prediction_ch1(min_max_normalize(inp_indi1, mixing_t_ood).cuda()).detach().cpu().numpy() #[mixing_t_ood] #
        pred_t_0= pred_t_0[0]
        pred_t_1= pred_t_1[0]

        if pred_t_0 < eps:
            pred_t_0 = 0
        if pred_t_1 < eps:
            pred_t_1 = 0
        if pred_t_0 > 1:
            pred_t_0 = 1
        if pred_t_1 > 1:
            pred_t_1 = 1
        
        pred_t_0_arr.append(pred_t_0)
        pred_t_1_arr.append(pred_t_1)

        # pred_ch0 = indi_model.inference(inp_indi0,clip_denoised=True, continous=False, t_float_start=np.mean(pred_t_0_arr[-10:]), num_timesteps=num_timesteps)
        # pred_ch1 = indi_model.inference(inp_indi1,clip_denoised=True, continous=False, t_float_start=np.mean(pred_t_1_arr[-10:]), num_timesteps=num_timesteps)
        pred_ch0 = indi_model.inference(inp_indi0, continuous=False, t_float_start=pred_t_0, num_timesteps=num_timesteps)
        pred_ch1 = indi_model.inference(inp_indi1, continuous=False, t_float_start=pred_t_1, num_timesteps=num_timesteps)
        
        # we ignore the other channel prediction. TODO: inspect that as well.  
        pred_ch0 = pred_ch0[:,0]
        pred_ch1 = pred_ch1[:,1]

        # old way of prediction
        # pred_ch0 = indi_model.indi1.p_sample_loop(inp_indi0, clip_denoised=True, continuous=False, num_timesteps=1, t_float_start=pred_t_0[0])
        # pred_ch1 = indi_model.indi2.p_sample_loop(inp_indi1, clip_denoised=True, continuous=False, num_timesteps=1, t_float_start=pred_t_1[0])
        
        pred = np.concatenate([pred_ch0.cpu().numpy(), pred_ch1.cpu().numpy()], axis=0)
        pred_unnorm = pred * norm_dict['std_target'] + norm_dict['mean_target']
        tar_unnorm = data['target'] * norm_dict['std_target'] + norm_dict['mean_target']
        if mmse_idx == 0:
            all_targets_ood.append(tar_unnorm[None])
        
        all_predictions_ood.append(pred_unnorm[None])

    all_predictions_ood = np.concatenate(all_predictions_ood, axis=0)
    all_mmse_predictions_ood.append(all_predictions_ood)

all_targets_ood = np.concatenate(all_targets_ood, axis=0)
all_inputs_ood = np.concatenate(all_inputs_ood, axis=0)

pred_t_0_arr = np.array(pred_t_0_arr)
pred_t_1_arr = np.array(pred_t_1_arr)
# Out:
#   0%|          | 0/490 [00:00<?, ?it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 49.99it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.69it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.25it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.15it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.21it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.07it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.14it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.46it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.22it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.14it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.69it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.18it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.15it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.12it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.73it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.25it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.24it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.08it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.10it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.98it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.10it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.45it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.75it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.26it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.46it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.19it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.19it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.36it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.75it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.27it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.20it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.69it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.01it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.05it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.01it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.22it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.24it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.28it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.38it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.45it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.18it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.69it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.12it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.24it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.11it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.08it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.25it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.17it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.12it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.23it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.12it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.19it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.30it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.36it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.30it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.28it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.38it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.46it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.25it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 43.26it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.36it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.98it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.28it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.99it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.21it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.38it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.15it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.23it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.15it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.08it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.98it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.28it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.45it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.36it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.24it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.20it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.73it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.25it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.30it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.36it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.21it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.75it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.28it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.18it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.08it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.20it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.14it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.46it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.38it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.23it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.21it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.30it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.14it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.15it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.19it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.28it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.11it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.34it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.75it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.45it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.34it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.08it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.34it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.33it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.98it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.75it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.21it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.15it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 46.34it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 48.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.93it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.99it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.93it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.12it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.82it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.82it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.01it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.24it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.34it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.82it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.20it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.10it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.21it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.08it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.15it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.98it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.10it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.98it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.38it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.73it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.34it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 47.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.38it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.29it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.75it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.17it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 48.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 44.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.88it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.17it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.33it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.84it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.26it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.75it/s]
# ...
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.69it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.93it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.19it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.26it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.93it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.46it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.24it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.25it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.93it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.05it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.11it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.90it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.32it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.00it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.95it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.51it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.43it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.16it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.27it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.26it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.27it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.18it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.07it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.20it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.35it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.64it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.71it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.36it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.31it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.73it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.33it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.16it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.63it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.12it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.22it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.83it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.25it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.93it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.42it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.62it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.01it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.60it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.26it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.49it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.68it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.07it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.13it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.45it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.81it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.01it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.17it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.99it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.54it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.73it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.48it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.80it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.38it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.40it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.85it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.89it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.08it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.45it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.73it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.97it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.33it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.33it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.70it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.06it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.12it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.65it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.28it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.18it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.75it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.58it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.47it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.45it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.79it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.46it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.52it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.87it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.98it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.39it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.92it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.78it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.10it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.56it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.73it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.66it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.14it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.61it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.02it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.03it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.59it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.50it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.77it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.33it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.91it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.67it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 50.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.41it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.04it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.37it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.53it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.74it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.44it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 51.86it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.72it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.76it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.57it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.96it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 53.09it/s]
# inference time step: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# 100%|██████████| 490/490 [03:25<00:00,  2.38it/s]

# %%
all_predictions_ood.shape
# Out:
# (490, 2, 512, 512)

# %%
len(all_mmse_predictions_ood)
# Out:
# 5

# %%
_,ax = plt.subplots(figsize=(6,6),nrows=2,ncols=2)
ax[0,0].imshow(all_inputs_ood[1,0])
ax[0,1].imshow(all_inputs_ood[1,1])
ax[1,0].imshow(all_predictions_ood[1,0])
ax[1,1].imshow(all_predictions_ood[1,1])

# %%
np.min(pred_t_1_arr)
# Out:
# 0.5

# %%
mmse_pred = 0 
for i in range(mmse_count):
    mmse_pred += all_mmse_predictions_ood[i]/mmse_count

# %%
from data.tile_stitcher import stitch_predictions

pred_stitched_ood = stitch_predictions(mmse_pred, val_set.tile_manager)
tar_stitched_ood = stitch_predictions(all_targets_ood, val_set.tile_manager)
# inputs_stitched_ood = stitch_predictions(all_inputs_ood, val_set.tile_manager)
# target_stitched_ood = np.stack(val_set._data_dict, axis=-1)
# Out:
# [10, 2048, 2048, 2]
# [10, 2048, 2048, 2]

# %%
from core.psnr import RangeInvariantPsnr
ch0psnr, ch1psnr = [RangeInvariantPsnr(tar_stitched_ood[...,i]*1.0, pred_stitched_ood[...,i]) for i in range(2)]
msg_psnr = f'T:{num_timesteps} W:{mixing_t_ood} M:{mmse_count} PSNR: N{num_timesteps} '
msg_psnr += f'Ch0: {ch0psnr.mean().item():.1f} +- {ch0psnr.std().item()/np.sqrt(len(ch0psnr)):.1f}\t'
msg_psnr += f'Ch1: {ch1psnr.mean().item():.1f} +- {ch1psnr.std().item()/np.sqrt(len(ch1psnr)):.1f}'
print(msg_psnr)
# Out:
# T:5 W:0.5 M:5 PSNR: N5 Ch0: 32.3 +- 0.9	Ch1: 34.6 +- 0.7

# %%
# predicted t

# actual t
# T:1 W:0.5 M:1 PSNR: N1 Ch0: 33.8 +- 0.8	Ch1: 36.0 +- 0.8
# T:1 W:0.5 M:5 PSNR: N1 Ch0: 33.9 +- 0.8	Ch1: 36.0 +- 0.8

# T:2 W:0.5 M:1 PSNR: N2 Ch0: 33.0 +- 0.9	Ch1: 35.4 +- 0.7
# T:2 W:0.5 M:5 PSNR: N2 Ch0: 33.1 +- 0.9	Ch1: 35.5 +- 0.7

# T:5 W:0.5 M:1 PSNR: N5 Ch0: 32.2 +- 0.9	Ch1: 34.5 +- 0.7
# T:5 W:0.5 M:5 PSNR: N5 Ch0: 32.3 +- 0.9	Ch1: 34.6 +- 0.7
